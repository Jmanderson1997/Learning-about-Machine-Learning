# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
training = pd.read_csv('train.csv')

#plt.plot(training['lstat'], training['medv'], 'r.')

plt.plot(training['lstat'], training['medv'], 'r.')
trainX = np.array(training['lstat']).reshape((-1, 1))
constants = np.ones(trainX.shape[0])
trainX = np.hstack((trainX, constants))

print (np.matmul())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-65644a679d11> in <module>()
#       6 trainX = np.array(training['lstat']).reshape((-1, 1))
#       7 constants = np.ones(trainX.shape[0])
# ----> 8 trainX = np.hstack((trainX, constants))
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/shape_base.py in hstack(tup)
#     291         return _nx.concatenate(arrs, 0)
#     292     else:
# --> 293         return _nx.concatenate(arrs, 1)
#     294
#     295
#
# ValueError: all the input arrays must have same number of dimensions
